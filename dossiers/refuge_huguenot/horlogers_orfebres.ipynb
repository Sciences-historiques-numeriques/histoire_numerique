# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# # Passages par Frankfort
#
# Michelle Magdelaine, « Le refuge huguenot, exil et accueil », Annales de Bretagne et des Pays de l’Ouest. Anjou. Maine. Poitou-Charente. Touraine, nᵒ 121‑3 (15 novembre 2014): 131‑43, https://doi.org/10.4000/abpo.2848
#
# Données issues du tableau : "Tableau 1 – Nombre de personnes passées par Francfort de 1686 à 1694" (p.140)

# %%
file = '/Volumes/Fortitudo/Documents/documentation_FB/enseignements/Neuchatel_cours_DH_unine/_donnees/refuge_huguenot/magdelaine_2014_passages_francfort.csv'

# %%
passages = pd.read_csv(file, '|', index_col=0)
passages
# Out:
#                        1686  1687  1688  1689  1690  1691  1692  1693  1694
# Années
# Hommes seuls           2273  2849  1884   479   572   621   689   554   310
# Femmes seules           262   413   436   330   696   912   982   805   338
# Conjoints ensemble      596   586   540   530   312   300   254   530   104
# Enfants avec prénom    230   217    95    31    20    45    38    18     7
# Enfants sans prénom    560   570   286   740   489   292   284   531   140

# %%
fig, ax = plt.subplots(figsize=(20,10))         
# Sample figsize in inches
g = sns.heatmap(passages, annot=passages, cmap="coolwarm", linewidths=.5, ax=ax)
labels = passages.index
p = g.set_yticklabels(labels, rotation=30)
